# %% [markdown]
# <a href="https://colab.research.google.com/github/KhushiChaudhary-cyber/python_programs/blob/main/dataframe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
path='/content/student_report_500.xlsx'
df=pd.read_excel(path)

# %%
#to display full data
print(df)
# Out:
#     Student_ID        Full_Name  Gender  Class Section        City  Maths  \
# 0     STD-1001  Priya Choudhary    Male     10       A  Chandigarh     45
# 1     STD-1002      Aarav Verma    Male      7       C     Kolkata     89
# 2     STD-1003         Sai Iyer    Male      8       C     Kolkata     48
# 3     STD-1004     Ananya Singh  Female      8       C     Kolkata     84
# 4     STD-1005  Shreya Kulkarni    Male      8       C  Chandigarh     71
# ..         ...              ...     ...    ...     ...         ...    ...
# 495   STD-1496     Ritika Gupta    Male      7       A       Patna     69
# 496   STD-1497       Rohan Iyer    Male      6       B     Kolkata     85
# 497   STD-1498       Meera Iyer    Male      9       A     Lucknow     98
# 498   STD-1499       Kavya Iyer  Female     10       A     Kolkata     84
# 499   STD-1500  Priya Choudhary  Female      7       A       Delhi     66
#
#      Science  English  Hindi  Social_Studies  Total  Percentage  Attendance  \
# ...

# %%
df.head(10)
# Out:
#   Student_ID        Full_Name  Gender  Class Section        City  Maths  \
# 0   STD-1001  Priya Choudhary    Male     10       A  Chandigarh     45
# 1   STD-1002      Aarav Verma    Male      7       C     Kolkata     89
# 2   STD-1003         Sai Iyer    Male      8       C     Kolkata     48
# 3   STD-1004     Ananya Singh  Female      8       C     Kolkata     84
# 4   STD-1005  Shreya Kulkarni    Male      8       C  Chandigarh     71
# 5   STD-1006   Aarav Kulkarni  Female      7       C       Delhi     97
# 6   STD-1007      Meera Gupta    Male      9       C     Lucknow     93
# 7   STD-1008      Kavya Gupta    Male      7       C      Bhopal     63
# 8   STD-1009     Vivaan Verma    Male      9       B     Kolkata     81
# 9   STD-1010  Ananya Banerjee  Female     10       A     Kolkata     74
#
#    Science  English  Hindi  Social_Studies  Total  Percentage  Attendance  \
# 0       97       58     76              71    347        69.4          84
# ...

# %%
# to print last five elements
df.tail(5)
# Out:
#     Student_ID        Full_Name  Gender  Class Section     City  Maths  \
# 495   STD-1496     Ritika Gupta    Male      7       A    Patna     69
# 496   STD-1497       Rohan Iyer    Male      6       B  Kolkata     85
# 497   STD-1498       Meera Iyer    Male      9       A  Lucknow     98
# 498   STD-1499       Kavya Iyer  Female     10       A  Kolkata     84
# 499   STD-1500  Priya Choudhary  Female      7       A    Delhi     66
#
#      Science  English  Hindi  Social_Studies  Total  Percentage  Attendance  \
# 495       80       96     76              50    371        74.2          92
# 496       98       49     86              48    366        73.2          79
# 497       83       64     96              61    402        80.4          74
# 498       76       62     60              64    346        69.2          64
# 499       54       81     44              61    306        61.2          71
#
#     Status
# 495   Pass
# 496   Pass
# 497   Pass
# 498   Pass
# 499   Pass

# %%
#to display random 10 records
df.sample(10)
# Out:
#     Student_ID         Full_Name  Gender  Class Section     City  Maths  \
# 361   STD-1362  Ritika Choudhary  Female     10       B  Lucknow     61
# 196   STD-1197        Rahul Jain  Female      7       B   Bhopal     73
# 458   STD-1459    Pooja Kulkarni  Female      6       B    Patna     85
# 62    STD-1063      Karan Sharma  Female      7       C    Patna     76
# 75    STD-1076       Sneha Verma  Female      6       C   Bhopal     62
# 248   STD-1249        Rahul Iyer    Male      6       C  Lucknow     70
# 482   STD-1483       Pooja Yadav    Male      6       A   Mumbai     84
# 492   STD-1493        Simran Das    Male     10       B   Mumbai     53
# 2     STD-1003          Sai Iyer    Male      8       C  Kolkata     48
# 152   STD-1153         Neha Kaur  Female      8       A  Kolkata     92
#
#      Science  English  Hindi  Social_Studies  Total  Percentage  Attendance  \
# 361       69       65     46              41    282        56.4          73
# ...

# %%
#to summarise the record
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Student_ID      500 non-null    object
#  1   Full_Name       500 non-null    object
#  2   Gender          500 non-null    object
#  3   Class           500 non-null    int64
#  4   Section         500 non-null    object
#  5   City            500 non-null    object
#  6   Maths           500 non-null    int64
#  7   Science         500 non-null    int64
#  8   English         500 non-null    int64
#  9   Hindi           500 non-null    int64
#  10  Social_Studies  500 non-null    int64
#  11  Total           500 non-null    int64
#  12  Percentage      500 non-null    float64
#  13  Attendance      500 non-null    int64
#  14  Status          500 non-null    object
# dtypes: float64(1), int64(8), object(6)
# memory usage: 58.7+ KB

# %%
#to display statistical summary
df.describe()
# Out:
#             Class       Maths     Science     English       Hindi  \
# count  500.000000  500.000000  500.000000  500.000000  500.000000
# mean     8.022000   69.852000   70.110000   69.734000   69.168000
# std      1.434445   17.883336   17.563908   17.520765   17.290857
# min      6.000000   40.000000   40.000000   40.000000   40.000000
# 25%      7.000000   54.000000   55.000000   54.000000   54.000000
# 50%      8.000000   71.000000   70.000000   70.000000   69.000000
# 75%      9.000000   85.000000   85.000000   84.000000   83.000000
# max     10.000000  100.000000  100.000000  100.000000  100.000000
#
#        Social_Studies       Total  Percentage  Attendance
# count      500.000000  500.000000  500.000000  500.000000
# mean        69.474000  348.338000   69.667600   80.568000
# std         17.326562   37.500671    7.500134   11.964769
# min         40.000000  232.000000   46.400000   60.000000
# 25%         54.000000  324.000000   64.800000   70.750000
# ...

# %%
#to display name of columns
df.columns
# Out:
# Index(['Student_ID', 'Full_Name', 'Gender', 'Class', 'Section', 'City',
#        'Maths', 'Science', 'English', 'Hindi', 'Social_Studies', 'Total',
#        'Percentage', 'Attendance', 'Status'],
#       dtype='object')

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 495    False
# 496    False
# 497    False
# 498    False
# 499    False
# Length: 500, dtype: bool
